# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
import utils as ut

# %%
df1 = pd.read_csv("GTA.csv",encoding="ISO-8859-1",low_memory=False)

# %%
df1 = df1.drop(['addnotes','related','INT_ANY','INT_MISC','INT_IDEO','INT_LOG','scite1','scite2','scite3'],1)

# %% [markdown]
# list(df1.columns.values)

# %%
for i in df1.columns:
    print(i)
df1.count
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# ...

# %%
df2 = df1[['iyear','imonth','iday','region_txt','success','nkill','targtype1_txt','nwound']]

# %%
for i in df2.columns:
    print(i)
# Out:
# iyear
# imonth
# iday
# region_txt
# success
# nkill
# targtype1_txt
# nwound

# %%
df2_sam = df2.sample(500)

# %%
len(df2_sam.index)
# Out:
# 500

# %%
df2_sam
# Out:
#         iyear  imonth  iday                   region_txt  success  nkill  \
# 136671   2014       8    23   Middle East & North Africa        1    1.0
# 146889   2015       4    24                   South Asia        1    0.0
# 144349   2015       2    16   Middle East & North Africa        0    0.0
# 83686    2007       7     8                   South Asia        1    1.0
# 139784   2014      11     4   Middle East & North Africa        1    0.0
# 52376    1992       8     5                South America        1    0.0
# 90148    2009       1     7                   South Asia        1    1.0
# 57393    1994      10     8               Western Europe        1    0.0
# 47047    1991       7     8                South America        1    0.0
# 79412    2006       1    23                   South Asia        1    1.0
# 121259   2013       9    20   Middle East & North Africa        1    8.0
# 77756    2005       4     9   Middle East & North Africa        1    0.0
# ...

# %%
# COMPUTE CASUALTIES

kills = df2_sam['nkill']
wounded = df2_sam['nwound']

df2_sam['casualties'] = kills + wounded

df2_sam.assign(casualties=kills+wounded)
# Out:
#         iyear  imonth  iday                   region_txt  success  nkill  \
# 136671   2014       8    23   Middle East & North Africa        1    1.0
# 146889   2015       4    24                   South Asia        1    0.0
# 144349   2015       2    16   Middle East & North Africa        0    0.0
# 83686    2007       7     8                   South Asia        1    1.0
# 139784   2014      11     4   Middle East & North Africa        1    0.0
# 52376    1992       8     5                South America        1    0.0
# 90148    2009       1     7                   South Asia        1    1.0
# 57393    1994      10     8               Western Europe        1    0.0
# 47047    1991       7     8                South America        1    0.0
# 79412    2006       1    23                   South Asia        1    1.0
# 121259   2013       9    20   Middle East & North Africa        1    8.0
# 77756    2005       4     9   Middle East & North Africa        1    0.0
# ...

# %%
print(df2.head)
# Out:
# <bound method NDFrame.head of         iyear  imonth  iday                   region_txt  success  nkill  \
# 0        1970       7     2  Central America & Caribbean        1    1.0
# 1        1970       0     0                North America        1    0.0
# 2        1970       1     0               Southeast Asia        1    1.0
# 3        1970       1     0               Western Europe        1    NaN
# 4        1970       1     0                    East Asia        1    NaN
# 5        1970       1     1                North America        1    0.0
# 6        1970       1     2                South America        0    0.0
# 7        1970       1     2                North America        1    0.0
# 8        1970       1     2                North America        1    0.0
# 9        1970       1     3                North America        1    0.0
# 10       1970       1     1                North America        0    0.0
# ...

# %%
regions = sub_df1.groupby('region_txt').count()
regions['nkill']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b343f2a0d66d> in <module>()
# ----> 1 regions = sub_df1.groupby('region_txt').count()
#       2 regions['nkill']
#
# NameError: name 'sub_df1' is not defined

# %%
sub_df1[['nkill','targtype1_txt']]

# %%
sub2_df1 = sub_df1[['nkill','iyear','success']].groupby(sub_df1['country_txt'])

# %%
# Number of Countries
len(sub2_df1)

# %%
sub2_df1.get_group('Syria')

# %%
type(df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-61a4f441e9ff> in <module>()
# ----> 1 type(df2)
#
# NameError: name 'df2' is not defined
