# %%
import pandas as pd
import matplotlib as plot
import numpy as np
import utils as ut
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %%
df1 = pd.read_csv("GTA.csv",encoding="ISO-8859-1",low_memory=False)

# %%
df1 = df1.drop(['natlty1','success','corp1','resolution','gname','targtype3','targtype2','targtype1','attacktype3','attacktype2','attacktype1','region','longitude','latitude','extended','approxdate','addnotes','related','INT_ANY','INT_MISC','INT_IDEO','INT_LOG','scite1','scite2','scite3'],1)

# %%
list(df1.columns.values)
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'country',
#  'country_txt',
#  'region_txt',
#  'provstate',
#  'city',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'suicide',
#  'attacktype1_txt',
#  'attacktype2_txt',
#  'attacktype3_txt',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'target1',
#  'natlty1_txt',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gsubname',
#  'gname2',
#  'gsubname2',
#  'gname3',
#  'gsubname3',
#  'motive',
#  'guncertain1',
#  'guncertain2',
#  'guncertain3',
#  'individual',
#  'nperps',
#  'nperpcap',
#  'claimed',
#  'claimmode',
#  'claimmode_txt',
#  'claim2',
#  'claimmode2',
#  'claimmode2_txt',
# ...

# %%
gta = df1[['iyear','region_txt','nkill','nwound','targtype1_txt','crit1','crit2','crit3']]

# %%
quantitative_data = df1[['region_txt','nkill','nwound']]

# %%
quantitative_data
# Out:
#                          region_txt  nkill  nwound
# 0       Central America & Caribbean    1.0     0.0
# 1                     North America    0.0     0.0
# 2                    Southeast Asia    1.0     0.0
# 3                    Western Europe    NaN     NaN
# 4                         East Asia    NaN     NaN
# 5                     North America    0.0     0.0
# 6                     South America    0.0     0.0
# 7                     North America    0.0     0.0
# 8                     North America    0.0     0.0
# 9                     North America    0.0     0.0
# 10                    North America    0.0     0.0
# 11                    North America    0.0     0.0
# 12                   Western Europe    0.0     0.0
# 13                    North America    0.0     0.0
# 14                    North America    0.0     0.0
# 15                   Eastern Europe    NaN     NaN
# 16               Sub-Saharan Africa    1.0     0.0
# ...

# %%
# COMPUTE CASUALTIES
# kills = gta.loc[:,('nkill')]
# wounded = gta.loc[:,('nwound')]
# gta.assign(casualties=kills+wounded)

# kills = quantitative_data.loc[:,('nkill')]
# wounded = quantitative_data.loc[:,('nwound')]

# %%
# Describe 
kills = gta.loc[:,('nkill')]
wounded = gta.loc[:,('nwound')]
quantitative_data.assign(casualties=kills+wounded)
# Out:
#                          region_txt  nkill  nwound  casualties
# 0       Central America & Caribbean    1.0     0.0         1.0
# 1                     North America    0.0     0.0         0.0
# 2                    Southeast Asia    1.0     0.0         1.0
# 3                    Western Europe    NaN     NaN         NaN
# 4                         East Asia    NaN     NaN         NaN
# 5                     North America    0.0     0.0         0.0
# 6                     South America    0.0     0.0         0.0
# 7                     North America    0.0     0.0         0.0
# 8                     North America    0.0     0.0         0.0
# 9                     North America    0.0     0.0         0.0
# 10                    North America    0.0     0.0         0.0
# 11                    North America    0.0     0.0         0.0
# 12                   Western Europe    0.0     0.0         0.0
# 13                    North America    0.0     0.0         0.0
# ...

# %%
quantitative_data.describe()
# Out:
#                nkill         nwound
# count  160668.000000  155025.000000
# mean        2.387246       3.200239
# std        11.327709      34.647365
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         2.000000       2.000000
# max      1500.000000    7366.000000
