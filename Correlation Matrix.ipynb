# %%
import pandas as pd
import matplotlib as plot
import numpy as np
import utils as ut
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %%
df1 = pd.read_csv("GTA.csv",encoding="ISO-8859-1",low_memory=False)

# %%
df1 = df1.drop(['natlty1','success','corp1','resolution','gname','targtype3','targtype2','targtype1','attacktype3','attacktype2','attacktype1','region','longitude','latitude','extended','approxdate','addnotes','related','INT_ANY','INT_MISC','INT_IDEO','INT_LOG','scite1','scite2','scite3'],1)

# %%
list(df1.columns.values)
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'country',
#  'country_txt',
#  'region_txt',
#  'provstate',
#  'city',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'suicide',
#  'attacktype1_txt',
#  'attacktype2_txt',
#  'attacktype3_txt',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'target1',
#  'natlty1_txt',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gsubname',
#  'gname2',
#  'gsubname2',
#  'gname3',
#  'gsubname3',
#  'motive',
#  'guncertain1',
#  'guncertain2',
#  'guncertain3',
#  'individual',
#  'nperps',
#  'nperpcap',
#  'claimed',
#  'claimmode',
#  'claimmode_txt',
#  'claim2',
#  'claimmode2',
#  'claimmode2_txt',
# ...

# %%
gta = df1[['iyear','region_txt','nkill','nwound','targtype1_txt','crit1','crit2','crit3']]

# %%
quantitative_data = df1[['iyear','region_txt','nkill','nwound']]

# %%
feature_data = df1[['region_txt','nkill','nwound','multiple']]

# %%
quantitative_data
# Out:
#         iyear                   region_txt  nkill  nwound
# 0        1970  Central America & Caribbean    1.0     0.0
# 1        1970                North America    0.0     0.0
# 2        1970               Southeast Asia    1.0     0.0
# 3        1970               Western Europe    NaN     NaN
# 4        1970                    East Asia    NaN     NaN
# 5        1970                North America    0.0     0.0
# 6        1970                South America    0.0     0.0
# 7        1970                North America    0.0     0.0
# 8        1970                North America    0.0     0.0
# 9        1970                North America    0.0     0.0
# 10       1970                North America    0.0     0.0
# 11       1970                North America    0.0     0.0
# 12       1970               Western Europe    0.0     0.0
# 13       1970                North America    0.0     0.0
# 14       1970                North America    0.0     0.0
# ...

# %%
# COMPUTE CASUALTIES
# kills = gta.loc[:,('nkill')]
# wounded = gta.loc[:,('nwound')]
# gta.assign(casualties=kills+wounded)

# kills = quantitative_data.loc[:,('nkill')]
# wounded = quantitative_data.loc[:,('nwound')]

# %%
# Describe 
kills = quantitative_data.loc[:,('nkill')]
wounded = quantitative_data.loc[:,('nwound')]
quantitative_data = quantitative_data.assign(casualties=kills+wounded)

# %%
clean_values = quantitative_data[np.isfinite(quantitative_data['casualties'])]

# %%
clean_values
# Out:
#         iyear                   region_txt  nkill  nwound  casualties
# 0        1970  Central America & Caribbean    1.0     0.0         1.0
# 1        1970                North America    0.0     0.0         0.0
# 2        1970               Southeast Asia    1.0     0.0         1.0
# 5        1970                North America    0.0     0.0         0.0
# 6        1970                South America    0.0     0.0         0.0
# 7        1970                North America    0.0     0.0         0.0
# 8        1970                North America    0.0     0.0         0.0
# 9        1970                North America    0.0     0.0         0.0
# 10       1970                North America    0.0     0.0         0.0
# 11       1970                North America    0.0     0.0         0.0
# 12       1970               Western Europe    0.0     0.0         0.0
# 13       1970                North America    0.0     0.0         0.0
# ...

# %% [raw]
# regions = summary_data[['nkill']].groupby(summary_data['region_txt']).size()

# %%
clean_values[['casualties']].groupby(clean_values['region_txt']).describe()
# Out:
#                             casualties                                        \
#                                  count       mean         std  min  25%  50%
# region_txt
# Australasia & Oceania            256.0   1.488281    4.200824  0.0  0.0  0.0
# Central America & Caribbean     7837.0   4.405385   12.385695  0.0  0.0  1.0
# Central Asia                     543.0   5.440147   35.293963  0.0  0.0  1.0
# East Asia                        747.0  13.283802  204.355142  0.0  0.0  0.0
# Eastern Europe                  4762.0   3.770475   21.463431  0.0  0.0  1.0
# Middle East & North Africa     43123.0   7.207036   22.803469  0.0  0.0  2.0
# North America                   3220.0   7.331677  219.067465  0.0  0.0  0.0
# South America                  16850.0   2.568131    8.363522  0.0  0.0  0.0
# South Asia                     39720.0   5.478424   18.212435  0.0  0.0  1.0
# Southeast Asia                 11031.0   3.553622   10.740582  0.0  0.0  1.0
# ...

# %%
clean_values
# Out:
#                          region_txt  nkill  nwound  casualties
# 0       Central America & Caribbean    1.0     0.0         1.0
# 1                     North America    0.0     0.0         0.0
# 2                    Southeast Asia    1.0     0.0         1.0
# 5                     North America    0.0     0.0         0.0
# 6                     South America    0.0     0.0         0.0
# 7                     North America    0.0     0.0         0.0
# 8                     North America    0.0     0.0         0.0
# 9                     North America    0.0     0.0         0.0
# 10                    North America    0.0     0.0         0.0
# 11                    North America    0.0     0.0         0.0
# 12                   Western Europe    0.0     0.0         0.0
# 13                    North America    0.0     0.0         0.0
# 14                    North America    0.0     0.0         0.0
# 16               Sub-Saharan Africa    1.0     0.0         1.0
# ...

# %%
clean_values[['nkill','casualties']].describe()
# Out:
#                nkill     casualties
# count  154524.000000  154524.000000
# mean        2.115943       5.312327
# std         9.782411      40.798412
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       1.000000
# 75%         2.000000       4.000000
# max      1383.000000    8749.000000

# %%
clean_values[['casualties']].groupby(clean_values['iyear']).describe()
# Out:
#       casualties
#            count       mean         std  min  25%  50%   75%     max
# iyear
# 1970       598.0   0.575251    2.963235  0.0  0.0  0.0   0.0    47.0
# 1971       325.0   0.366154    1.916004  0.0  0.0  0.0   0.0    27.0
# 1972       167.0   3.598802   15.102485  0.0  0.0  0.0   1.0   132.0
# 1973       244.0   2.545082   16.851629  0.0  0.0  0.0   1.0   239.0
# 1974       346.0   2.956647   12.304865  0.0  0.0  0.0   1.0    95.0
# 1975       395.0   1.977215    9.845867  0.0  0.0  0.0   1.0   127.0
# 1976       618.0   1.868932   13.174947  0.0  0.0  0.0   1.0   295.0
# 1977      1100.0   0.794545    4.224540  0.0  0.0  0.0   0.0   100.0
# 1978      1297.0   2.053971   14.991824  0.0  0.0  0.0   1.0   422.0
# 1979      2197.0   1.990897    6.193591  0.0  0.0  0.0   1.0   100.0
# 1980      2121.0   3.546912   13.827024  0.0  0.0  1.0   2.0   300.0
# 1981      1878.0   4.316294   14.914355  0.0  0.0  1.0   3.0   383.0
# ...

# %%
max_year = clean_values[['casualties']].groupby(clean_values['iyear'])

# %%
max_year.get_group(2014)
# Out:
#         casualties
# 125149         0.0
# 125150        24.0
# 125151        34.0
# 125152         0.0
# 125154         8.0
# 125155         5.0
# 125156        16.0
# 125157         0.0
# 125158         0.0
# 125159         1.0
# 125160         3.0
# 125161         0.0
# 125162         1.0
# 125163         0.0
# 125164         0.0
# 125165         0.0
# 125166         0.0
# 125167         0.0
# 125168         0.0
# 125169         0.0
# 125170         0.0
# 125171         0.0
# 125172         0.0
# 125173         3.0
# 125174         9.0
# 125175        27.0
# 125176         0.0
# 125177        18.0
# 125178         2.0
# 125179         8.0
# 125180         1.0
# 125181         1.0
# 125182         0.0
# 125183         0.0
# 125184         0.0
# 125185         1.0
# 125186         0.0
# 125187         1.0
# 125188         1.0
# 125189        10.0
# 125190         0.0
# 125191        22.0
# 125192         3.0
# 125193         1.0
# 125194         1.0
# 125195        10.0
# ...

# %%
len(max_year.get_group(2014))
# Out:
# 14964

# %%
clean_values['nkill'][clean_values['iyear'] == '2014']
# Out:
# /Users/matthewatwell/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py:798: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-4babcab0e6b4> in <module>()
# ----> 1 clean_values['nkill'][clean_values['iyear'] == '2014']
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     859
#     860             with np.errstate(all='ignore'):
# --> 861                 res = na_op(values, other)
#     862             if is_scalar(res):
#     863                 raise TypeError('Could not compare %s type with Series' %
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     798                     result = getattr(x, name)(y)
# ...
